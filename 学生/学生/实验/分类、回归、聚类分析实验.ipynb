# %% [markdown]
# <h1 align=center>实验4 分类、回归、聚类分析实验</h1>

# %% [markdown]
# ### 2022 - 2023 年第2学期

# %% [markdown]
# * 专业：20软件工程
# * 班级：
# * 学号：
# * 姓名：

# %% [markdown]
# ## 一、实验目的
#
# 1、掌握经典分类模型方法。
#
# 2、掌握分类预测模型性能分析方法。
#
# 3、掌握使用python实现分类模型方法进行分类预测、模型性能分析。
#
# 4、掌握经典回归模型估计方法和参数假设检验。
#
# 5、掌握回归预测模型性能分析方法。
#
# 6、掌握使用python实现回归模型估计和参数假设检验、模型分析。
#
# 7、掌握层次聚类法的基本原理、思想和方法；
#
# 8、掌握层次聚类命令scipy.cluster.hierarchy、sch.linkage、sch.dendrogram的使用方法；
#
# 9、熟练对多维数据进行层次聚类数据挖掘。

# %% [markdown]
# ## 二、	实验要求
#
# 1、理解经典分类算法；
#
# 2、熟练掌握分类预测模型性能分析方法；
#
# 3、使用pandas，statsmodels，sklearn库函数对音乐风格分类数据进行分析，建立分类模型，比较模型效果。
#
# 4、理解回归模型，参数估计和参数假设检验方法；
#
# 5、熟练掌握回归预测模型性能分析方法；
#
# 6、使用pandas，statsmodels，sklearn库函数对数据进行分析，建立回归模型，检验模型效果。
#
# 7、安装好python聚类库；
#
# 8、使用层次聚类算法进行分析；
#
# 9、使用绘图库matplotlib绘出聚类树图和数字编号图；

# %% [markdown]
# ## 三、	 实验内容
#
# #### 最低要求：分类、回归、聚类任选其一
#
# ### 分类
#
# 音乐风格分类数据集(https://www.kaggle.com/datasets/harish24/music-genre-classification)
#
# 属性包括如下：
#
# - chroma_stft
#
# Chroma features 是音乐音频的一种有趣而强大的表示，其中整个频谱被投射到 12 个 bins 上，代表音乐八度音阶的 12 个不同的半音（或色度）。
#
# - rmse
#
# 表征信号能量的方法，原始歌声的声学特征。
#
# - spectral_centroid
#
# 代表了声音的“质心”所在位置，与整个长度相同的布鲁斯风格歌曲相比，金属歌曲在结尾处有更高的频率，频谱频谱质心将接近其末端。
#
# - spectral_bandwidth
#
# 音乐频谱带宽。
#
# - rolloff
#
# 信号形状的度量，表示每帧的滚降系数。即表示总频谱能量的百分比（例如 85%）低于该频率。
#
# - zero_crossing_rate
#
# 信号从正变为负或反向的速率，已大量用于语音识别和音乐信息检索。对于金属和摇滚中的高打击乐声音，它通常具有更高的值
#
# - mfcc1-mfcc20
#
# Mel-Frequency Cepstral Coefficients - the way in which humans perceive sound（梅尔频率倒谱系数），一组特征，简明地描述了频谱包络的整体形状，可以模拟人声的特征。
#
# - 目标变量是label
#
# 音乐风格类别标签（共10类）
#
# #### 要求：
#
# 1、读取数据,生成训练和测试数据集（20%）；
#
# 2、使用K邻近分类算法进行分类预测，并评价预测性能，给出Train和Test数据集的f1，accuracy，分析结果；
#
# 3、使用SVM进行分类预测，并给出Train和Test数据集的f1，accuracy，分析结果；
#
# 4、构造决策树进行分类预测，并给出Train和Test数据集的f1，accuracy，分析结果；
#
# 5、使用随机森林算法进行分类预测，给出Train和Test数据集的f1，accuracy，分析结果；
#
# 6、使用lightgbm模型进行分类预测，给出Train和Test数据集的f1，accuracy，分析结果；
#
# 7、使用交叉验证模型选择方法，指定scoring为accuracy，对KNN、SVM、Decision Tree，Random Forest进行模型选择（根据平均cv评分）,并画出最好的分类模型的roc曲线。
#
# ### 回归
#
# 社交媒体影响力数据集 Social Media Influencer(https://www.kaggle.com/datasets/ramjasmaurya/top-1000-social-media-channels)
#
# 属性包括：
#
# - Tiktoker name 和Tiktok name
#
# 抖音用户名和平台用户姓名
#
# - Subscribers count
#
# 订阅粉丝量
#
# - Views avg.
#
# 播放量
#
# - Likes avg
#
# 点赞量
#
# - Comments avg.
#
# 评论数
#
# - Shares avg
#
# 转发量
#
# #### 要求：
#
# 1、数据预处理，清理数据，并对K(1000)和M(1e6)进行转换，确保粉丝量、播放量、点赞量、评论数、转发量均为数值型数据；
#
# 2、想探讨什么因素会影响<font color="red">点赞量</font>并如何影响，据此确定特征X和目标变量Y，生成训练和测试数据集（20%）；
#
# 3、建立回归模型多元回归模型，使用训练数据进行拟合，解释拟合结果，给出Train和Test score，检验模型效果；
#
# 4、使用正则化方法，建立回归模型，进行拟合，给出Train和Test score，检验模型效果；
#
# 5、建立级联模型（自定），进行拟合，给出Train和Test score，检验模型效果；
#
# 6、建立集成学习模型（自选，xgboost回归模型，LightGBM回归模型，随机森林回归模型等），给出Train和Test score，检验模型效果；
#
# 7、使用交叉验证模型选择方法(10-fold)，指定scoring为r2，对上述多元回归、正则化方法和集成学习模型进行模型选择（根据平均cv评分）。
#
# ### 聚类
#
# spotify上排名前50音乐曲目数据集Top 50 Music Data (https://www.kaggle.com/datasets/leonardopena/top50spotify2019
#
# https://www.kaggle.com/code/emilytries/top-50-music-data-clustering/input)
#
# 属性包括：
#
# - Track_Name
#
# 专辑名
#
# - Artist_Name
#
# 歌手名
#
# - Genre
#
# 音乐风格
#
# - Beats_Per_Minute
#
# 每分钟节拍数
#
# - Energy
#
# 音乐能量
#
# - Danceability
#
# 律动感
#
# - Loudness_DB
#
# 响度，单位分贝
#
# - Liveness
#
# 现场感
#
# - Valence
#
# 心理感受，该值越高表示音乐给人的感受更正向，积极
#
# - Length
#
# 音乐时长
#
# - Acousticness
#
# 原声程度
#
# - Speechiness
#
# 朗诵比例
#
# - Popularity
#
# 受欢迎度
#
#
# #### 要求：
#
# 1、读取数据，对数据预处理，并对音乐风格进行转换和选择合适的编码：
#
# 风格：hip hop（atl hip hop，canadian hip hop，trap music），pop（australian pop，canadian pop，dance pop，panamanian pop，pop，pop house，boy band，escape room），reggaeton（reggaeton，reggaeton flow），electronic（big room，brostep，edm，electropop），rap（country rap，dfw rap），latin（latin），R&B（r&b en espanol）
#
# 2、Beats_Per_Minute，Energy，Danceability，Loudness_DB，Liveness，Valence，Length，Acousticness，Speechiness这9个特征作为音乐聚类分析的特征，对数据进行标准化变换；
#
# 3、利用linkage计算簇与簇之间的三种距离。 linkage(y, method=’single’, metric=’euclidean’)，分别取single:最近邻的簇间距、complete:最远邻的簇间距、average:平均距离；
#
# 4、利用sch.dendrogram画出三种距离下的树状图；
#
# 5、使用沃德方差最小化法进行层次聚类 method='ward'，依次标出已知的簇和生成的新簇，显示聚类过程；
#
# 6、考虑平均距离的簇间距，进行聚类的结果分析，指出7个簇下包含哪些音乐曲目,并将聚类分析结果与题1中的风格大类进行比较。
#
# 7、选取“Beats_Per_Minute，Energy，Danceability，Length”四个特征，采用K均值进行聚类（k=4），画出音乐风格聚类的雷达图（蜘蛛图）。

# %% [markdown]
# ## 四、 实验过程和步骤
#
# (本节写出具体步骤和代码）

# %% [markdown]
# ## 五、	实验心得
